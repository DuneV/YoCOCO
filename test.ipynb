# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

load_dotenv()
# DB CONFIG
DB_SCHEMA   = os.getenv("DB_SCHEMA", "aura_info")
DB_HOST     = os.getenv("DATABASE_HOST")
DB_PORT     = int(os.getenv("DATABASE_PORT", "5432"))
DB_NAME     = os.getenv("DATABASE_NAME")
DB_USER     = os.getenv("DATABASE_USERNAME")
DB_PASSWORD = os.getenv("DATABASE_PASSWORD")

db_url = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

engine = create_engine(db_url)

df = pd.read_sql("SELECT * FROM aura_info.video_analyses", engine)

df.head()
# Out:
# Empty DataFrame
# Columns: [id, video_name, frame_fps, duration_sec, frame_count, yolo_objects, arms_pose, summary, meta, created_at]
# Index: []

# %%
with open('test.json', 'w') as f:
    f.write(str(df['yolo_objects'].iloc[0]))

# %%
import os, json, math
import numpy as np
from uuid import UUID
from dotenv import load_dotenv
import copy
from IPython.display import HTML, display, clear_output
from ipywidgets import Output, VBox
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import patches
from ipywidgets import interactive, IntSlider, Text

matplotlib.rcParams['figure.dpi'] = 160
plt.ioff()

from db.db import Database
from db_models import VideoAnalysis

load_dotenv()
output_area = Output()


# GLOBAL STATE
loaded_data = {
    "map_y": {}, "map_h": {}, "frame_ids": [], "W": 0, "H": 0,
    "title_name": "", "n_frames": 0, "fig": None, "ax": None,
    "rect_patches": [], "label_texts": [], "hand_points": [], "hand_labels": []
}


def listar_ids_videoanalysis(info):
    """Devuelve una lista con todos los IDs (UUID)."""
    return info['id']

def load_video_analysis(video_analysis_id, df):
    """Carga los datos desde el DataFrame df (ya en RAM)."""

    if not video_analysis_id:
        print("Ingrese un ID.")
        return False

    try:
        vid_str = str(UUID(str(video_analysis_id)))
    except:
        print("ERROR: ID debe ser un UUID válido.")
        return False
    
    row = df[df["id"].astype(str) == vid_str]

    if row.empty:
        print(f"No existe ese ID en el DataFrame.")
        return False

    row = row.iloc[0]  # convertir a serie

    data_yolo = copy.deepcopy(row["yolo_objects"])
    data_arms = copy.deepcopy(row["arms_pose"])
    title_name = row["video_name"]

    map_y = {it.get("frame_idx"): it for it in data_yolo}
    map_h = {it.get("frame_idx"): it for it in data_arms}

    frame_ids = sorted(set(map_y.keys()) | set(map_h.keys()))
    n_frames = len(frame_ids)

    def detect_canvas():
        max_x = max_y = 0
        for it in data_yolo:
            for d in it.get("detections", []):
                x1,y1,x2,y2 = map(float, d.get("bbox",[0,0,0,0]))
                max_x = max(max_x, x1, x2)
                max_y = max(max_y, y1, y2)
        for it in data_arms:
            for h in it.get("hands", []):
                for key in ("wrist","index_tip"):
                    p = h.get(key,{})
                    x = float(p.get("x",0))
                    y = float(p.get("y",0))
                    max_x = max(max_x, x)
                    max_y = max(max_y, y)
        return int(max(max_x, 1280)), int(max(max_y, 720))

    W, H = detect_canvas()

    if loaded_data["fig"]:
        plt.close(loaded_data["fig"])

    fig, ax = plt.subplots(figsize=(W/160, H/160), dpi=160)
    ax.set_xlim(0, W)
    ax.set_ylim(H, 0)
    ax.set_aspect("equal")
    plt.close(fig)

    loaded_data.update({
        "map_y": map_y,
        "map_h": map_h,
        "frame_ids": frame_ids,
        "W": W,
        "H": H,
        "title_name": title_name,
        "n_frames": n_frames,
        "fig": fig,
        "ax": ax,
        "rect_patches": [],
        "label_texts": [],
        "hand_points": [],
        "hand_labels": []
    })

    print(f"Video cargado (desde DataFrame): {title_name} — Frames: {n_frames}")
    return True


def _clear_artists():
    for key in ["rect_patches", "label_texts", "hand_points", "hand_labels"]:
        for artist in loaded_data[key]:
            artist.remove()
        loaded_data[key].clear()


def draw_frame(frame_pos):

    if loaded_data["n_frames"] == 0:
        return loaded_data["fig"]

    _clear_artists()
    ax = loaded_data["ax"]
    fid = loaded_data["frame_ids"][frame_pos]

    y = loaded_data["map_y"].get(fid, {})
    h = loaded_data["map_h"].get(fid, {})

    for d in y.get("detections", []):
        try:
            x1,y1,x2,y2 = map(float, d.get("bbox", [0,0,0,0]))
            rect = patches.Rectangle((x1, y1), x2-x1, y2-y1,
                                    fill=False, color="cyan", linewidth=1.5)
            ax.add_patch(rect)
            loaded_data["rect_patches"].append(rect)

            txt = ax.text(
                x1, y1 - 4,
                f"{d.get('label')} {float(d.get('conf',0)):.2f}",
                fontsize=7, color="white", backgroundcolor="black"
            )
            loaded_data["label_texts"].append(txt)
        except:
            continue

    for hand in h.get("hands", []):
        hand_label = hand.get("label", "").capitalize()  # Left / Right

        # Wrist
        wr = hand.get("wrist", {})
        if "x" in wr and "y" in wr:
            wx, wy = float(wr["x"]), float(wr["y"])
            
            wrist_point_color = "blue"

            # Etiqueta
            txt_wrist = ax.text(
                wx + 10, wy - 10,
                f"{hand_label} wrist",
                fontsize=9,
                color="blue",
                weight="bold"
            )
            loaded_data["hand_labels"].append(txt_wrist)

            pt_wrist, = ax.plot(wx, wy, marker="o", markersize=10,
                                color=wrist_point_color)
            loaded_data["hand_points"].append(pt_wrist)

        # Index tip
        it = hand.get("index_tip", {})
        if "x" in it and "y" in it:
            ix, iy = float(it["x"]), float(it["y"])

            idx_point_color = "red"

            txt_idx = ax.text(
                ix + 10, iy - 10,
                f"{hand_label} index",
                fontsize=9,
                color="red",
                weight="bold"
            )
            loaded_data["hand_labels"].append(txt_idx)

            pt_idx, = ax.plot(ix, iy, marker="x", markersize=10,
                            color=idx_point_color)
            loaded_data["hand_points"].append(pt_idx)

    ax.set_title(
        f"{loaded_data['title_name']} — Frame {frame_pos+1}/{loaded_data['n_frames']} (ID: {fid})"
    )

    return loaded_data["fig"]


def ver_video_por_id(video_analysis_id):
    """Carga un video por UUID y muestra slider + figura en un Output estable."""
    
    ok = load_video_analysis(video_analysis_id)
    if not ok:
        return
    
    output_area.clear_output()

    slider = IntSlider(
        min=0,
        max=loaded_data["n_frames"] - 1,
        value=0,
        step=1,
        description="Frame:",
        continuous_update=False
    )

    def update(change):
        frame_pos = change["new"]
        fig = draw_frame(frame_pos)

        with output_area:
            output_area.clear_output(wait=True)
            display(fig)

    slider.observe(update, names="value")

    first_fig = draw_frame(0)
    with output_area:
        output_area.clear_output()
        display(first_fig)

    display(VBox([slider, output_area]))

id_text = Text(
    value="",
    placeholder="Ingrese UUID",
    description="Video ID:",
    disabled=False
)

def handle_enter(change):
    if change["name"] == "value":
        ver_video_por_id(change["new"])

id_text.observe(handle_enter, names="value")

# %%
df.info()

# %%
df["id"].head()
df["id"].dtype

# %%
df['summary'][0]

# %%
from ipywidgets import Button, HBox
import time

def play_video(video_analysis_id, df, fps=10):
    """Reproduce todos los frames automáticamente."""
    
    ok = load_video_analysis(video_analysis_id, df)
    if not ok:
        return
    
    n = loaded_data["n_frames"]
    fig = loaded_data["fig"]
    ax  = loaded_data["ax"]

    delay = 1.0 / fps
    
    print(f"Reproduciendo '{loaded_data['title_name']}' a {fps} FPS ({n} frames).")
    
    for i in range(n):
        draw_frame(i)
        display(fig)
        time.sleep(delay)
        clear_output(wait=True)

    print("Reproducción finalizada.")

play_button = Button(
    description="Play",
    button_style="success",
    layout={'width': '120px'}
)

def on_play_button_clicked(b):
    video_id = id_text.value.strip()
    if video_id:
        play_video(video_id, fps=10)
    else:
        print("Ingrese un UUID primero.")

# %%
play_video('8fd81b62-2711-49f6-90fc-217325011071', df, fps=120)

# %%
listar_ids_videoanalysis(df)

# %%
# interactions_knn.py
# -*- coding: utf-8 -*-
from __future__ import annotations

import os, math, json, uuid, csv, time
from dataclasses import dataclass
from typing import List, Dict, Any, Tuple, Optional, Iterable, DefaultDict
from collections import defaultdict, Counter

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

import matplotlib
matplotlib.use("Agg")  # headless
import matplotlib.pyplot as plt

from dotenv import load_dotenv
load_dotenv()

# ================== CONFIG ==================
DB_SCHEMA         = os.getenv("DB_SCHEMA", "aura_info")
DB_HOST           = os.getenv("DATABASE_HOST")
DB_PORT           = int(os.getenv("DATABASE_PORT", os.getenv("PORT", "5432")))
DB_NAME           = os.getenv("DATABASE_NAME")
DB_USER           = os.getenv("DATABASE_USERNAME")
DB_PASSWORD       = os.getenv("DATABASE_PASSWORD")

OBJECT_LABELS     = set(json.loads(os.getenv("OBJECT_LABELS", "null"))) if os.getenv("OBJECT_LABELS") else None
WRIST_LABELS      = set(json.loads(os.getenv("WRIST_LABELS", '["Left","Right"]')))
PROXIMITY_PX      = float(os.getenv("PROXIMITY_PX", "20.0"))

MIN_SEG_FRAMES    = int(os.getenv("MIN_SEG_FRAMES", "3"))
GAP_TOLERANCE     = int(os.getenv("GAP_TOLERANCE", "1"))

CLUSTER_METHOD    = os.getenv("CLUSTER_METHOD", "kmeans")        # "kmeans"|"spectral"
AUTO_N_CLUSTERS   = os.getenv("AUTO_N_CLUSTERS", "1") == "1"
MAX_CLUSTERS      = int(os.getenv("MAX_CLUSTERS", "8"))
FIXED_CLUSTERS    = int(os.getenv("FIXED_CLUSTERS", "5"))
PCA_VARIANCE      = float(os.getenv("PCA_VARIANCE", "0.95"))

WRITE_CSV         = os.getenv("WRITE_CSV", "1") == "1"
OUT_DIR           = os.getenv("OUT_DIR", "data_temp")

# ---- Global / preview ----
GLOBAL_LIMIT_VIDEOS          = int(os.getenv("GLOBAL_LIMIT_VIDEOS", "0"))     # 0 = sin límite
GLOBAL_MIN_SEGMENTS_PER_VID  = int(os.getenv("GLOBAL_MIN_SEGMENTS_PER_VID", "1"))
PREVIEW_ONLY                 = os.getenv("PREVIEW_ONLY", "1") == "1"          # por defecto SOLO previsualiza
PLOT_FORMAT                  = os.getenv("PLOT_FORMAT", "png")                # png|svg
PLOT_DPI                     = int(os.getenv("PLOT_DPI", "150"))

# ---- Guardado DB ----
USE_DB            = os.getenv("USE_DB", "1") == "1"
SAVE_MODELS       = os.getenv("SAVE_MODELS", "0") == "1"
MODELS_DIR        = os.getenv("MODELS_DIR", "models_motion")
LABELS_CSV        = os.getenv("LABELS_CSV", "")

# ================== DB & MODELOS ==================
from db.db import Database
from sqlalchemy import text as sql_text
from db_models import VideoAnalysis

# ================== GEOMETRÍA ==================
def point_in_bbox(x: float, y: float, bbox: Iterable[float]) -> bool:
    try: x1, y1, x2, y2 = bbox
    except Exception: return False
    return (x1 <= x <= x2) and (y1 <= y <= y2)

def point_to_rect_distance(x: float, y: float, bbox: Iterable[float]) -> float:
    try: x1, y1, x2, y2 = bbox
    except Exception: return float("inf")
    dx = max(x1 - x, 0.0, x - x2)
    dy = max(y1 - y, 0.0, y - y2)
    return math.hypot(dx, dy)

def bbox_center(bbox: Iterable[float]) -> Tuple[float, float]:
    x1, y1, x2, y2 = bbox
    return (0.5 * (x1 + x2), 0.5 * (y1 + y2))

def vel(a: Tuple[float, float], b: Tuple[float, float]) -> Tuple[float, float, float]:
    vx = b[0] - a[0]; vy = b[1] - a[1]
    return vx, vy, math.hypot(vx, vy)

# ================== DATA CLASSES ==================
@dataclass
class HandPoint:
    x: float; y: float; z: float; label: str

@dataclass
class Detection:
    label: str; conf: float; bbox: Tuple[float, float, float, float]

@dataclass
class FrameData:
    frame_idx: int; time_sec: float; hands: List[HandPoint]; dets: List[Detection]

@dataclass
class InteractionEvent:
    frame_idx: int; time_sec: float; wrist: str; wrist_xy: Tuple[float,float]
    obj_label: str; bbox: Tuple[float,float,float,float]; inside: bool; near: bool; dist: float

@dataclass
class MotionSegment:
    segment_id: str; video_id: str; wrist: str; obj_label: str
    start_frame: int; end_frame: int; start_time: float; end_time: float
    frames: List[int]

# ================== HELPERS ==================
def deterministic_segment_id(video_id: str, wrist: str, obj: str, start_f: int, end_f: int) -> str:
    seed = f"{video_id}:{wrist}:{obj}:{start_f}:{end_f}"
    return str(uuid.uuid5(uuid.NAMESPACE_URL, seed))

def align_frames(yolo: List[Dict[str, Any]], hands: List[Dict[str, Any]]) -> List[FrameData]:
    map_y = {it["frame_idx"]: it for it in yolo}
    map_h = {it["frame_idx"]: it for it in hands}
    keys = sorted(set(map_y.keys()) | set(map_h.keys()))
    out: List[FrameData] = []
    for k in keys:
        y, h = map_y.get(k), map_h.get(k)
        if not y and not h: continue
        t = (y or h).get("time_sec", None)
        dets, hands_list = [], []
        if y:
            for d in y.get("detections", []):
                bbox = tuple(map(float, d.get("bbox", [0,0,0,0])))
                dets.append(Detection(label=str(d.get("label","")), conf=float(d.get("conf",0.0)), bbox=bbox))
        if h:
            for hh in h.get("hands", []):
                wr = hh.get("wrist", {})
                hands_list.append(HandPoint(float(wr.get("x",-1)), float(wr.get("y",-1)), float(wr.get("z",0)), str(hh.get("label",""))))
        out.append(FrameData(k, float(t if t is not None else -1), hands_list, dets))
    return out

def compute_interactions(frames: List[FrameData],
                         obj_labels: Optional[set],
                         wrist_labels: Optional[set],
                         proximity_px: float) -> List[InteractionEvent]:
    evs: List[InteractionEvent] = []
    for fr in frames:
        if not fr.hands or not fr.dets: continue
        for h in fr.hands:
            if wrist_labels and h.label not in wrist_labels: continue
            for d in fr.dets:
                if obj_labels is not None and d.label not in obj_labels: continue
                inside = point_in_bbox(h.x, h.y, d.bbox)
                dist = 0.0 if inside else point_to_rect_distance(h.x, h.y, d.bbox)
                if inside or dist <= proximity_px:
                    evs.append(InteractionEvent(fr.frame_idx, fr.time_sec, h.label, (h.x,h.y), d.label, d.bbox, inside, True, dist))
    return evs

def _make_segment(video_id: str, wrist: str, obj: str, run: List[InteractionEvent]) -> MotionSegment:
    start, end = run[0].frame_idx, run[-1].frame_idx
    times = [ev.time_sec for ev in run if ev.time_sec is not None]
    st = float(times[0]) if times else -1.0
    et = float(times[-1]) if times else -1.0
    seg_id = deterministic_segment_id(video_id, wrist, obj, start, end)
    return MotionSegment(seg_id, video_id, wrist, obj, start, end, st, et, [ev.frame_idx for ev in run])

def build_segments(video_id: str, events: List[InteractionEvent],
                   min_len: int, gap_tol: int) -> List[MotionSegment]:
    by_pair: DefaultDict[Tuple[str,str], List[InteractionEvent]] = defaultdict(list)
    for ev in events: by_pair[(ev.wrist, ev.obj_label)].append(ev)
    segments: List[MotionSegment] = []
    for (wrist, obj), lst in by_pair.items():
        lst.sort(key=lambda e: e.frame_idx)
        run: List[InteractionEvent] = []; last = None
        for ev in lst:
            if not run: run=[ev]; last=ev.frame_idx; continue
            gap = ev.frame_idx - (last if last is not None else ev.frame_idx)
            if gap <= (gap_tol + 1):
                run.append(ev)
            else:
                if len(run) >= min_len: segments.append(_make_segment(video_id, wrist, obj, run))
                run=[ev]
            last = ev.frame_idx
        if run and len(run) >= min_len:
            segments.append(_make_segment(video_id, wrist, obj, run))
    return segments

def build_frame_index(frames: List[FrameData]) -> Dict[int, FrameData]:
    return {f.frame_idx: f for f in frames}

def extract_segment_features(frames: List[FrameData], segments: List[MotionSegment]) -> Tuple[pd.DataFrame, List[str]]:
    idx = build_frame_index(frames)
    rows = []
    feat_cols = [
        "duration_frames","duration_sec","speed_mean","speed_max","path_len",
        "dist_center_mean","dist_center_min","inside_ratio","dx_end_start","dy_end_start"
    ]
    for seg in segments:
        fs = sorted(seg.frames)
        if len(fs) < 2: continue
        pts, centers, inside_flags = [], [], []
        for fr in fs:
            frd = idx.get(fr); 
            if not frd: continue
            wp = None
            for h in frd.hands:
                if h.label == seg.wrist: wp=(h.x,h.y); break
            if not wp: continue
            cands = [d.bbox for d in frd.dets if d.label == seg.obj_label]
            if not cands: continue
            dists = [point_to_rect_distance(wp[0], wp[1], bb) for bb in cands]
            bb = cands[int(np.argmin(dists))]; c = bbox_center(bb)
            pts.append(wp); centers.append(c); inside_flags.append(1 if point_in_bbox(wp[0], wp[1], bb) else 0)
        if len(pts) < 2: continue
        speeds=[]; path_len=0.0
        for a,b in zip(pts[:-1], pts[1:]):
            _,_,v = vel(a,b); speeds.append(v); path_len += v
        dcenter = [math.hypot(px-cx, py-cy) for (px,py),(cx,cy) in zip(pts,centers)]
        row = {
            "segment_id": seg.segment_id,
            "video_id": seg.video_id,
            "wrist": seg.wrist,
            "obj_label": seg.obj_label,
            "start_frame": seg.start_frame,
            "end_frame": seg.end_frame,
            "start_time": seg.start_time,
            "end_time": seg.end_time,
            "duration_frames": len(pts),
            "duration_sec": max(0.0, float(seg.end_time - seg.start_time)) if (seg.end_time>=0 and seg.start_time>=0) else float("nan"),
            "speed_mean": float(np.mean(speeds)) if speeds else 0.0,
            "speed_max":  float(np.max(speeds)) if speeds else 0.0,
            "path_len":   path_len,
            "dist_center_mean": float(np.mean(dcenter)) if dcenter else float("nan"),
            "dist_center_min":  float(np.min(dcenter)) if dcenter else float("nan"),
            "inside_ratio": float(np.mean(inside_flags)) if inside_flags else 0.0,
            "dx_end_start": pts[-1][0]-pts[0][0],
            "dy_end_start": pts[-1][1]-pts[0][1],
        }
        rows.append(row)
    return pd.DataFrame(rows), feat_cols

# ================== CLUSTERING ==================
def choose_n_clusters(X: np.ndarray, method: str, max_k: int = 8) -> int:
    best_k, best_score = 2, -1.0
    for k in range(2, max_k+1):
        if method == "kmeans":
            labels = KMeans(n_clusters=k, n_init="auto", random_state=42).fit_predict(X)
        else:
            labels = SpectralClustering(n_clusters=k, affinity='nearest_neighbors', n_neighbors=max(2, min(10, len(X)-1)), random_state=42).fit_predict(X)
        if len(set(labels)) < 2: continue
        score = silhouette_score(X, labels, metric="euclidean")
        if score > best_score: best_score, best_k = score, k
    return best_k

def cluster_global(seg_df: pd.DataFrame, feat_cols: List[str], method: str, auto_k: bool, max_k: int, fixed_k: int, pca_var: float):
    if seg_df.empty: return seg_df.assign(cluster=-1), {"empty":True}, None, None, None
    X = seg_df[feat_cols].fillna(seg_df[feat_cols].mean()).to_numpy(float)
    scaler = StandardScaler(); Xs = scaler.fit_transform(X)
    pca = PCA(n_components=min(len(feat_cols), len(seg_df)-1), svd_solver="full")
    Xp_full = pca.fit_transform(Xs)
    if pca_var < 1.0:
        cum = np.cumsum(pca.explained_variance_ratio_); kdim = int(np.searchsorted(cum, pca_var) + 1)
        Xp = Xp_full[:, :max(2, kdim)]
    else:
        Xp = Xp_full
    k = choose_n_clusters(Xp, method, max_k) if auto_k else max(2, fixed_k)
    if method == "kmeans":
        model = KMeans(n_clusters=k, n_init="auto", random_state=42); labels = model.fit_predict(Xp)
        centers_2d = model.cluster_centers_[:, :2] if Xp.shape[1] >= 2 else None
    else:
        model = SpectralClustering(n_clusters=k, affinity='nearest_neighbors', n_neighbors=max(2, min(10, len(Xp)-1)), assign_labels='kmeans', random_state=42)
        labels = model.fit_predict(Xp); centers_2d = None
    out = seg_df.copy(); out["cluster"] = labels
    info = {
        "method": method, "k": int(k), "n_segments": int(len(out)),
        "feature_cols": feat_cols,
        "explained_var": float(np.sum(pca.explained_variance_ratio_[:Xp.shape[1]])),
        "scaler_mean": scaler.mean_.tolist(), "scaler_scale": scaler.scale_.tolist()
    }
    return out, info, Xp, pca, scaler

# ================== SUPERVISADO (opcional) ==================
def optional_supervised(seg_df: pd.DataFrame, feat_cols: List[str]):
    if not LABELS_CSV or not os.path.exists(LABELS_CSV): return {}
    lbl = {}
    with open(LABELS_CSV, "r", encoding="utf-8") as f:
        for r in csv.DictReader(f): lbl[r["segment_id"]] = r["label"]
    df = seg_df.copy(); df["label"] = df["segment_id"].map(lbl); df = df.dropna(subset=["label"])
    if df.empty: return {}
    X = df[feat_cols].fillna(df[feat_cols].mean()).to_numpy(float); y = df["label"].astype(str).to_numpy()
    Xtr,Xte,ytr,yte = train_test_split(X,y,test_size=0.25,random_state=42,stratify=y)
    knn = Pipeline([("scaler",StandardScaler()),("clf",KNeighborsClassifier(n_neighbors=5))]); knn.fit(Xtr,ytr); acc_knn = float(knn.score(Xte,yte))
    svm = Pipeline([("scaler",StandardScaler()),("clf",SVC(kernel="rbf",probability=True,gamma="scale"))]); svm.fit(Xtr,ytr); acc_svm = float(svm.score(Xte,yte))
    if SAVE_MODELS:
        os.makedirs(MODELS_DIR, exist_ok=True)
        try:
            import joblib
            joblib.dump(knn, os.path.join(MODELS_DIR,"knn_motion.pkl"))
            joblib.dump(svm, os.path.join(MODELS_DIR,"svm_motion.pkl"))
        except Exception as e:
            print(f"[WARN] No se pudieron guardar modelos: {e}")
    return {"knn_acc":acc_knn, "svm_acc":acc_svm}

# ================== DB PERSISTENCIA ==================
def _pick_uuid_func(conn):
    r = conn.execute(sql_text("SELECT to_regproc('gen_random_uuid()')")).scalar()
    if r: return "gen_random_uuid"
    r = conn.execute(sql_text("SELECT to_regproc('uuid_generate_v4()')")).scalar()
    if r: return "uuid_generate_v4"
    try: conn.execute(sql_text("CREATE EXTENSION IF NOT EXISTS pgcrypto"))
    except Exception: pass
    r = conn.execute(sql_text("SELECT to_regproc('gen_random_uuid()')")).scalar()
    if r: return "gen_random_uuid"
    try: conn.execute(sql_text('CREATE EXTENSION IF NOT EXISTS "uuid-ossp"'))
    except Exception: pass
    r = conn.execute(sql_text("SELECT to_regproc('uuid_generate_v4()')")).scalar()
    if r: return "uuid_generate_v4"
    raise RuntimeError("No hay función UUID (pgcrypto/uuid-ossp).")

def ensure_tables(db: Database):
    with db.engine.begin() as conn:
        uuidf = _pick_uuid_func(conn)
        # runs globales
        conn.execute(sql_text(f"""
        CREATE TABLE IF NOT EXISTS "{DB_SCHEMA}".motion_runs (
          id UUID PRIMARY KEY DEFAULT {uuidf}(),
          created_at TIMESTAMPTZ NOT NULL DEFAULT now(),
          method TEXT, k INT, n_segments INT, info JSONB
        );"""))
        # segmentos
        conn.execute(sql_text(f"""
        CREATE TABLE IF NOT EXISTS "{DB_SCHEMA}".motion_segments (
          id UUID PRIMARY KEY DEFAULT {uuidf}(),
          video_analysis_id UUID NOT NULL REFERENCES "{DB_SCHEMA}".video_analyses(id) ON DELETE CASCADE,
          run_id UUID REFERENCES "{DB_SCHEMA}".motion_runs(id) ON DELETE SET NULL,
          segment_id TEXT NOT NULL UNIQUE,
          wrist TEXT NOT NULL,
          obj_label TEXT NOT NULL,
          start_frame INT NOT NULL,
          end_frame   INT NOT NULL,
          start_time  DOUBLE PRECISION,
          end_time    DOUBLE PRECISION,
          features    JSONB,
          cluster     INT
        );"""))
        # clusters por video (opcional, mismo método/k por corrida)
        conn.execute(sql_text(f"""
        CREATE TABLE IF NOT EXISTS "{DB_SCHEMA}".motion_clusters (
          id UUID PRIMARY KEY DEFAULT {uuidf}(),
          video_analysis_id UUID NOT NULL REFERENCES "{DB_SCHEMA}".video_analyses(id) ON DELETE CASCADE,
          run_id UUID REFERENCES "{DB_SCHEMA}".motion_runs(id) ON DELETE SET NULL,
          method TEXT, k INT, n_segments INT, info JSONB
        );"""))
        # columns que podrían faltar si vienes de versión previa
        conn.execute(sql_text(f'ALTER TABLE "{DB_SCHEMA}".motion_segments ADD COLUMN IF NOT EXISTS run_id UUID REFERENCES "{DB_SCHEMA}".motion_runs(id) ON DELETE SET NULL'))
        conn.execute(sql_text(f'ALTER TABLE "{DB_SCHEMA}".motion_clusters ADD COLUMN IF NOT EXISTS run_id UUID REFERENCES "{DB_SCHEMA}".motion_runs(id) ON DELETE SET NULL'))
        # índices
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS idx_ms_va ON "{DB_SCHEMA}".motion_segments (video_analysis_id)'))
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS idx_ms_run ON "{DB_SCHEMA}".motion_segments (run_id)'))
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS idx_ms_cluster ON "{DB_SCHEMA}".motion_segments (cluster)'))
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS idx_mc_va ON "{DB_SCHEMA}".motion_clusters (video_analysis_id)'))
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS idx_mc_run ON "{DB_SCHEMA}".motion_clusters (run_id)'))
        conn.execute(sql_text(f'CREATE INDEX IF NOT EXISTS gin_ms_features ON "{DB_SCHEMA}".motion_segments USING GIN (features)'))

def save_global_results(db: Database, clustered_df: pd.DataFrame, info: Dict[str,Any], feat_cols: List[str]) -> str:
    """Crea motion_runs y persiste segmentos y meta por video con ese run_id."""
    ensure_tables(db)
    with db.engine.begin() as conn:
        run_id = conn.execute(sql_text(f"""
            INSERT INTO "{DB_SCHEMA}".motion_runs (method, k, n_segments, info)
            VALUES (:m,:k,:n,:i::jsonb) RETURNING id
        """), {"m":info.get("method"), "k":info.get("k"), "n":info.get("n_segments"), "i":json.dumps(info)}).scalar()

    # upsert segmentos por video
    with db.engine.begin() as conn:
        for _, r in clustered_df.iterrows():
            feats = {c: (float(r[c]) if pd.notna(r[c]) else None) for c in feat_cols}
            conn.execute(sql_text(f"""
            INSERT INTO "{DB_SCHEMA}".motion_segments
                (video_analysis_id, run_id, segment_id, wrist, obj_label, start_frame, end_frame, start_time, end_time, features, cluster)
            VALUES
                (:vid, :run, :sid, :w, :obj, :sf, :ef, :st, :et, :feats::jsonb, :cl)
            ON CONFLICT (segment_id) DO UPDATE SET
                run_id = EXCLUDED.run_id,
                wrist  = EXCLUDED.wrist,
                obj_label = EXCLUDED.obj_label,
                start_frame = EXCLUDED.start_frame,
                end_frame   = EXCLUDED.end_frame,
                start_time  = EXCLUDED.start_time,
                end_time    = EXCLUDED.end_time,
                features    = EXCLUDED.features,
                cluster     = EXCLUDED.cluster
            """), {
                "vid": r["video_id"],
                "run": run_id,
                "sid": r["segment_id"],
                "w": r["wrist"],
                "obj": r["obj_label"],
                "sf": int(r["start_frame"]),
                "ef": int(r["end_frame"]),
                "st": float(r["start_time"]) if pd.notna(r["start_time"]) else None,
                "et": float(r["end_time"]) if pd.notna(r["end_time"]) else None,
                "feats": json.dumps(feats),
                "cl": int(r["cluster"]) if pd.notna(r["cluster"]) else None
            })
    # opcional: una fila motion_clusters por video con el método/k de esta corrida
    with db.engine.begin() as conn:
        vids = clustered_df["video_id"].unique().tolist()
        for vid in vids:
            nseg = int((clustered_df["video_id"]==vid).sum())
            conn.execute(sql_text(f"""
                INSERT INTO "{DB_SCHEMA}".motion_clusters (video_analysis_id, run_id, method, k, n_segments, info)
                VALUES (:vid, :run, :m, :k, :n, :i::jsonb)
            """), {"vid":vid, "run":run_id, "m":info.get("method"), "k":info.get("k"),
                   "n":nseg, "i":json.dumps({"from_global_run":True})})
    return str(run_id)

# ================== PLOTTING ==================
def plot_clusters_2d(Xp: np.ndarray, labels: np.ndarray, out_path: str, title: str = "K-Means preview"):
    """Usa las 2 primeras componentes de Xp para un scatter coloreado por cluster."""
    assert Xp.shape[1] >= 2, "Se requieren al menos 2 componentes para graficar."
    plt.figure(figsize=(8,6))
    # colores por cluster (matplotlib decide la paleta)
    for cl in sorted(set(labels)):
        mask = labels == cl
        plt.scatter(Xp[mask,0], Xp[mask,1], s=10, label=f"C{cl}", alpha=0.7)
    plt.xlabel("PC1"); plt.ylabel("PC2"); plt.title(title)
    plt.legend(markerscale=2)
    plt.tight_layout()
    plt.savefig(out_path, dpi=PLOT_DPI)
    plt.close()

# ================== CARGA GLOBAL ==================
def iter_all_videos(db: Database, limit: int = 0):
    """Genera (video_id, yolo_objects, arms_pose) de toda la tabla, ordenado por created_at asc."""
    with db.session() as s:
        q = s.query(VideoAnalysis).order_by(VideoAnalysis.created_at.asc())
        if limit and limit > 0: q = q.limit(limit)
        for row in q.all():
            yield str(row.id), row.yolo_objects, row.arms_pose

def process_video_to_segments(video_id: str, yolo_objects: List[Dict[str,Any]], arms_pose: List[Dict[str,Any]],
                              obj_labels: Optional[set], wrist_labels: Optional[set],
                              proximity_px: float, min_seg_frames: int, gap_tol: int) -> Tuple[pd.DataFrame, List[str]]:
    frames = align_frames(yolo_objects, arms_pose)
    evs = compute_interactions(frames, obj_labels=obj_labels, wrist_labels=wrist_labels, proximity_px=proximity_px)
    segs = build_segments(video_id, evs, min_len=min_seg_frames, gap_tol=gap_tol)
    # etiqueta video_id en cada segment_id ya viene dentro del determinístico
    seg_df, feat_cols = extract_segment_features(frames, segs)
    return seg_df, feat_cols

# ================== MAIN ==================
def main():
    os.makedirs(OUT_DIR, exist_ok=True)

    db = Database(
        host=DB_HOST, port=DB_PORT, database=DB_NAME,
        user=DB_USER, password=DB_PASSWORD,
        sslmode="require", models_module="db_models", schema=DB_SCHEMA
    )

    all_dfs = []
    feat_cols_ref: Optional[List[str]] = None
    n_videos = 0
    n_segments_total = 0

    for video_id, yolo, hands in iter_all_videos(db, limit=GLOBAL_LIMIT_VIDEOS):
        seg_df, feat_cols = process_video_to_segments(
            video_id, yolo, hands,
            obj_labels=OBJECT_LABELS, wrist_labels=WRIST_LABELS,
            proximity_px=PROXIMITY_PX, min_seg_frames=MIN_SEG_FRAMES, gap_tol=GAP_TOLERANCE
        )
        if seg_df is None or seg_df.empty:
            continue
        if len(seg_df) < GLOBAL_MIN_SEGMENTS_PER_VID:
            continue
        all_dfs.append(seg_df)
        feat_cols_ref = feat_cols
        n_videos += 1
        n_segments_total += len(seg_df)

    if not all_dfs:
        print("[WARN] No se generaron segmentos en ningún video. Ajusta filtros/proximidad.")
        return

    big = pd.concat(all_dfs, ignore_index=True)
    print(f"[INFO] Videos usados: {n_videos} | Segmentos totales: {len(big)}")

    clustered_df, info, Xp, pca, scaler = cluster_global(
        big, feat_cols_ref, method=CLUSTER_METHOD,
        auto_k=AUTO_N_CLUSTERS, max_k=MAX_CLUSTERS, fixed_k=FIXED_CLUSTERS, pca_var=PCA_VARIANCE
    )
    if info.get("empty"):
        print("[WARN] Clustering vacío.")
        return

    # ---------- PREVIEW ----------
    ts = int(time.time())
    preview_path = os.path.join(OUT_DIR, f"preview_{CLUSTER_METHOD}_k{info['k']}_{ts}.{PLOT_FORMAT}")
    if Xp is not None and Xp.shape[1] >= 2:
        plot_clusters_2d(Xp[:, :2], clustered_df["cluster"].to_numpy(), preview_path,
                         title=f"{CLUSTER_METHOD} k={info['k']} (n={info['n_segments']})")
        print(f"[PREVIEW] Figura guardada en: {preview_path}")
    else:
        print("[PREVIEW] No se pudo graficar (menos de 2 componentes).")

    if WRITE_CSV:
        big_path = os.path.join(OUT_DIR, f"segments_all_{ts}.csv")
        out_path = os.path.join(OUT_DIR, f"segments_all_clustered_{ts}.csv")
        big.to_csv(big_path, index=False)
        clustered_df.to_csv(out_path, index=False)
        print(f"[CSV] Features: {big_path}")
        print(f"[CSV] Clustered: {out_path}")

    # Supervisado opcional sobre el global
    sup = optional_supervised(clustered_df, feat_cols_ref)
    if sup:
        print(f"[SUP] KNN acc={sup.get('knn_acc',float('nan')):.3f} | SVM acc={sup.get('svm_acc',float('nan')):.3f}")

    # ---------- GUARDADO EN DB ----------
    if PREVIEW_ONLY:
        print("[INFO] PREVIEW_ONLY=1, no se escriben resultados a la DB. Si quieres persistir, export PREVIEW_ONLY=0")
        return

    if USE_DB:
        run_id = save_global_results(db, clustered_df, info, feat_cols_ref)
        print(f"[DB] Guardado global en run_id={run_id} con k={info['k']} (n={info['n_segments']})")

    # Top clusters
    counts = Counter(clustered_df["cluster"])
    top = counts.most_common(5)
    print("[TOP] clusters más frecuentes:", top)

if __name__ == "__main__":
    main()
# Out:
# [INFO] Videos usados: 44 | Segmentos totales: 7137
# [PREVIEW] Figura guardada en: data_temp/preview_kmeans_k4_1763662453.png
# [CSV] Features: data_temp/segments_all_1763662453.csv
# [CSV] Clustered: data_temp/segments_all_clustered_1763662453.csv
# [INFO] PREVIEW_ONLY=1, no se escriben resultados a la DB. Si quieres persistir, export PREVIEW_ONLY=0

# %%
# %% SOLO KNN + SVM DE MOVIMIENTOS
# Condición: la muñeca DEBE estar DENTRO del bbox de un objeto != 'person'
# No guarda nada; imprime métricas. Pensado para correr en Jupyter.

import os, math, json, uuid
from dataclasses import dataclass
from typing import List, Dict, Any, Tuple, Optional, Iterable, DefaultDict
from collections import defaultdict

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, silhouette_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from dotenv import load_dotenv
load_dotenv()

# =================== CONFIG ===================
DB_SCHEMA         = os.getenv("DB_SCHEMA", "aura_info")
DB_HOST           = os.getenv("DATABASE_HOST")
DB_PORT           = int(os.getenv("DATABASE_PORT", os.getenv("PORT", "5432")))
DB_NAME           = os.getenv("DATABASE_NAME")
DB_USER           = os.getenv("DATABASE_USERNAME")
DB_PASSWORD       = os.getenv("DATABASE_PASSWORD")

WRIST_LABELS      = set(json.loads(os.getenv("WRIST_LABELS", '["Left","Right"]')))
MIN_SEG_FRAMES    = int(os.getenv("MIN_SEG_FRAMES", "3"))
GAP_TOLERANCE     = int(os.getenv("GAP_TOLERANCE", "1"))

AUTO_N_CLUSTERS   = os.getenv("AUTO_N_CLUSTERS", "1") == "1"  # usar silhouette si True
MAX_CLUSTERS      = int(os.getenv("MAX_CLUSTERS", "8"))
FIXED_CLUSTERS    = int(os.getenv("FIXED_CLUSTERS", "5"))     # si AUTO_N_CLUSTERS=False
PCA_VARIANCE      = float(os.getenv("PCA_VARIANCE", "0.95"))

GLOBAL_LIMIT_VIDEOS         = int(os.getenv("GLOBAL_LIMIT_VIDEOS", "0"))  # 0 = todos
GLOBAL_MIN_SEGMENTS_PER_VID = int(os.getenv("GLOBAL_MIN_SEGMENTS_PER_VID", "1"))

# =================== DB ===================
from db.db import Database
from db_models import VideoAnalysis

db = Database(
    host=DB_HOST, port=DB_PORT, database=DB_NAME,
    user=DB_USER, password=DB_PASSWORD,
    sslmode="require", models_module="db_models", schema=DB_SCHEMA
)

# =================== Helpers geom ===================
def point_in_bbox(x: float, y: float, bbox: Iterable[float]) -> bool:
    try: x1,y1,x2,y2 = bbox
    except Exception: return False
    return (x1 <= x <= x2) and (y1 <= y <= y2)

def bbox_center(bbox: Iterable[float]) -> Tuple[float, float]:
    x1,y1,x2,y2 = bbox
    return (0.5*(x1+x2), 0.5*(y1+y2))

def vel(a: Tuple[float,float], b: Tuple[float,float]) -> Tuple[float,float,float]:
    vx = b[0]-a[0]; vy = b[1]-a[1]
    return vx, vy, math.hypot(vx, vy)

# =================== Tipos ===================
@dataclass
class HandPoint:
    x: float; y: float; z: float; label: str

@dataclass
class Detection:
    label: str; conf: float; bbox: Tuple[float,float,float,float]

@dataclass
class FrameData:
    frame_idx: int; time_sec: float; hands: List[HandPoint]; dets: List[Detection]

def align_frames(yolo: List[Dict[str, Any]], hands: List[Dict[str, Any]]) -> List[FrameData]:
    my = {it["frame_idx"]: it for it in yolo}
    mh = {it["frame_idx"]: it for it in hands}
    keys = sorted(set(my) | set(mh))
    out: List[FrameData] = []
    for k in keys:
        y, h = my.get(k), mh.get(k)
        if not y and not h: continue
        t = (y or h).get("time_sec", None)
        dets, hs = [], []
        if y:
            for d in y.get("detections", []):
                bbox = tuple(map(float, d.get("bbox", [0,0,0,0])))
                dets.append(Detection(str(d.get("label","")), float(d.get("conf",0.0)), bbox))
        if h:
            for hh in h.get("hands", []):
                wr = hh.get("wrist", {})
                hs.append(HandPoint(float(wr.get("x",-1)), float(wr.get("y",-1)), float(wr.get("z",0)), str(hh.get("label",""))))
        out.append(FrameData(k, float(t if t is not None else -1.0), hs, dets))
    return out

# =================== Interacciones y segmentos ===================
@dataclass
class InteractionEvent:
    frame_idx: int; time_sec: float
    wrist: str; wrist_xy: Tuple[float,float]
    obj_label: str; bbox: Tuple[float,float,float,float]

def compute_interactions_inside_only(frames: List[FrameData]) -> List[InteractionEvent]:
    """
    SOLO eventos donde la muñeca está DENTRO del bbox de un objeto != 'person'.
    """
    evs: List[InteractionEvent] = []
    for fr in frames:
        if not fr.hands or not fr.dets: continue
        for h in fr.hands:
            if WRIST_LABELS and h.label not in WRIST_LABELS: continue
            for d in fr.dets:
                if d.label == "person":  # descartar personas
                    continue
                if point_in_bbox(h.x, h.y, d.bbox):
                    evs.append(InteractionEvent(fr.frame_idx, fr.time_sec, h.label, (h.x,h.y), d.label, d.bbox))
    return evs

@dataclass
class MotionSegment:
    segment_id: str; video_id: str; wrist: str; obj_label: str
    start_frame: int; end_frame: int; start_time: float; end_time: float
    frames: List[int]

def _make_segment(video_id: str, wrist: str, obj: str, run: List[InteractionEvent]) -> MotionSegment:
    start, end = run[0].frame_idx, run[-1].frame_idx
    st = float(run[0].time_sec if run[0].time_sec is not None else -1.0)
    et = float(run[-1].time_sec if run[-1].time_sec is not None else -1.0)
    # ID determinista
    seed = f"{video_id}:{wrist}:{obj}:{start}:{end}"
    seg_id = str(uuid.uuid5(uuid.NAMESPACE_URL, seed))
    return MotionSegment(seg_id, video_id, wrist, obj, start, end, st, et, [ev.frame_idx for ev in run])

def build_segments(events: List[InteractionEvent], video_id: str,
                   min_len: int = MIN_SEG_FRAMES, gap_tol: int = GAP_TOLERANCE) -> List[MotionSegment]:
    by_pair: DefaultDict[Tuple[str,str], List[InteractionEvent]] = defaultdict(list)
    for ev in events:
        by_pair[(ev.wrist, ev.obj_label)].append(ev)
    segments: List[MotionSegment] = []
    for (wrist, obj), lst in by_pair.items():
        lst.sort(key=lambda e: e.frame_idx)
        run: List[InteractionEvent] = []
        last = None
        for ev in lst:
            if not run:
                run=[ev]; last=ev.frame_idx; continue
            gap = ev.frame_idx - (last if last is not None else ev.frame_idx)
            if gap <= (gap_tol + 1):
                run.append(ev)
            else:
                if len(run) >= min_len:
                    segments.append(_make_segment(video_id, wrist, obj, run))
                run=[ev]
            last = ev.frame_idx
        if run and len(run) >= min_len:
            segments.append(_make_segment(video_id, wrist, obj, run))
    return segments

# =================== Features ===================
def extract_features(frames: List[FrameData], segments: List[MotionSegment]) -> Tuple[pd.DataFrame, List[str]]:
    idx = {f.frame_idx: f for f in frames}
    rows = []
    feat_cols = [
        "duration_frames","duration_sec",
        "speed_mean","speed_max","path_len",
        "dx_end_start","dy_end_start"
    ]
    for seg in segments:
        fs = sorted(seg.frames)
        if len(fs) < 2: continue
        pts = []
        for fr in fs:
            frd = idx.get(fr); 
            if not frd: continue
            # muñeca específica del segmento
            wp = None
            for h in frd.hands:
                if h.label == seg.wrist:
                    wp = (h.x, h.y); break
            if not wp: continue
            pts.append(wp)
        if len(pts) < 2: continue

        speeds=[]; path_len=0.0
        for a,b in zip(pts[:-1], pts[1:]):
            _,_,v = vel(a,b); speeds.append(v); path_len += v

        rows.append({
            "segment_id": seg.segment_id, "video_id": seg.video_id,
            "wrist": seg.wrist, "obj_label": seg.obj_label,
            "start_frame": seg.start_frame, "end_frame": seg.end_frame,
            "start_time": seg.start_time, "end_time": seg.end_time,
            "duration_frames": len(pts),
            "duration_sec": max(0.0, seg.end_time - seg.start_time) if (seg.end_time>=0 and seg.start_time>=0) else float("nan"),
            "speed_mean": float(np.mean(speeds)) if speeds else 0.0,
            "speed_max":  float(np.max(speeds)) if speeds else 0.0,
            "path_len":   path_len,
            "dx_end_start": pts[-1][0]-pts[0][0],
            "dy_end_start": pts[-1][1]-pts[0][1],
        })
    return pd.DataFrame(rows), feat_cols

# =================== Dataset: TODOS los videos ===================
def iter_all(db: Database, limit: int = 0):
    with db.session() as s:
        q = s.query(VideoAnalysis).order_by(VideoAnalysis.created_at.asc())
        if limit and limit > 0: q = q.limit(limit)
        for row in q.all():
            yield str(row.id), row.yolo_objects, row.arms_pose

dfs = []
for vid, yolo, hands in iter_all(db, GLOBAL_LIMIT_VIDEOS):
    frames = align_frames(yolo, hands)
    evs = compute_interactions_inside_only(frames)     # <--- condición “inside” y objeto != person
    segs = build_segments(evs, vid, MIN_SEG_FRAMES, GAP_TOLERANCE)
    df, cols = extract_features(frames, segs)
    if df.empty: continue
    if len(df) < GLOBAL_MIN_SEGMENTS_PER_VID: continue
    dfs.append(df)

if not dfs:
    raise RuntimeError("No se generaron segmentos con la condición (wrist inside & obj != person). Ajusta MIN_SEG_FRAMES/GAP_TOLERANCE.")

data = pd.concat(dfs, ignore_index=True)
feat_cols = cols
print(f"[DATA] segmentos={len(data)}  videos={data['video_id'].nunique()}  objetos_unicos={data['obj_label'].nunique()}")

# =================== Embedding para ML ===================
X_raw = data[feat_cols].fillna(data[feat_cols].mean()).to_numpy(float)
scaler = StandardScaler().fit(X_raw)
X_s = scaler.transform(X_raw)

pca = PCA(n_components=min(X_s.shape[1], len(data)-1), svd_solver="full").fit(X_s)
Xp_full = pca.transform(X_s)
# mantener var explicada PCA_VARIANCE (mín 2 dims por estabilidad)
cum = np.cumsum(pca.explained_variance_ratio_)
pca_dim = max(2, int(np.searchsorted(cum, PCA_VARIANCE) + 1))
Xp = Xp_full[:, :min(pca_dim, Xp_full.shape[1])]

# =================== Pseudo-etiquetas de “movimiento” con KMeans ===================
def choose_k(X: np.ndarray, max_k: int = 8) -> int:
    best_k, best_s = 2, -1.0
    for k in range(2, max(3, min(max_k, len(X)-1))+1):
        labels = KMeans(n_clusters=k, n_init="auto", random_state=42).fit_predict(X)
        if len(set(labels)) < 2: continue
        s = silhouette_score(X, labels, metric="euclidean")
        if s > best_s: best_s, best_k = s, k
    return best_k

k = choose_k(Xp, MAX_CLUSTERS) if AUTO_N_CLUSTERS else max(2, FIXED_CLUSTERS)
km = KMeans(n_clusters=k, n_init="auto", random_state=42).fit(Xp)
y_movement = km.labels_.astype(int)
data["movement"] = y_movement
print(f"[KMEANS] k={k}  (usado solo para crear etiquetas de movimiento)")

# =================== Train/Test y modelos ===================
X_train, X_test, y_train, y_test = train_test_split(
    Xp, y_movement, test_size=0.25, random_state=42, stratify=y_movement
)

# KNN (movimiento)
knn = KNeighborsClassifier(n_neighbors=5, weights="distance")
knn.fit(X_train, y_train)
knn_acc = knn.score(X_test, y_test)

# SVM (movimiento)
svm = SVC(kernel="rbf", gamma="scale", decision_function_shape="ovr")
svm.fit(X_train, y_train)
svm_acc = svm.score(X_test, y_test)

print(f"[KNN] acc movimiento: {knn_acc:.3f}")
print(f"[SVM] acc movimiento: {svm_acc:.3f}")

# Reportes
print("\n[SVM] classification report:\n", classification_report(y_test, svm.predict(X_test)))
print("[KNN] classification report:\n", classification_report(y_test, knn.predict(X_test)))

# Matrices de confusión
cm_svm = confusion_matrix(y_test, svm.predict(X_test), labels=sorted(np.unique(y_movement)))
cm_knn = confusion_matrix(y_test, knn.predict(X_test), labels=sorted(np.unique(y_movement)))
print("\n[CM] SVM:\n", pd.DataFrame(cm_svm,
        index=[f"true:{l}" for l in sorted(np.unique(y_movement))],
        columns=[f"pred:{l}" for l in sorted(np.unique(y_movement))]))
print("\n[CM] KNN:\n", pd.DataFrame(cm_knn,
        index=[f"true:{l}" for l in sorted(np.unique(y_movement))],
        columns=[f"pred:{l}" for l in sorted(np.unique(y_movement))]))

# ========== Función auxiliar para usar el modelo luego ==========
def predict_movement(model, segment_feature_row: Dict[str, float]) -> int:
    """
    Recibe un dict con las columnas de 'feat_cols' y devuelve el ID de movimiento predicho.
    """
    x = np.array([[segment_feature_row[c] for c in feat_cols]], dtype=float)
    xs = scaler.transform(x)
    xe = pca.transform(xs)[:, :Xp.shape[1]]
    return int(model.predict(xe)[0])

print("\nListo. Usa `predict_movement(svm, row_dict)` o `predict_movement(knn, row_dict)` para nuevos segmentos.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 228
#     225     dfs.append(df)
#     227 if not dfs:
# --> 228     raise RuntimeError("No se generaron segmentos con la condición (wrist inside & obj != person). Ajusta MIN_SEG_FRAMES/GAP_TOLERANCE.")
#     230 data = pd.concat(dfs, ignore_index=True)
#     231 feat_cols = cols
#
# RuntimeError: No se generaron segmentos con la condición (wrist inside & obj != person). Ajusta MIN_SEG_FRAMES/GAP_TOLERANCE.
